# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# # Importing the data

# %%
df = pd.read_csv(r"C:\Users\ACER\Desktop\ML\01-Simple-Linear-Regression\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # Visualising the data on a scatter plot

# %%
# %matplotlib inline
plt.xlabel('area(sq. ft.)')
plt.ylabel('price(sq. ft.)')
plt.scatter(df.area, df.price, color = "red", marker = '+')

# %% [markdown]
# # Training the linear model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the price of an arbitary area

# %%
reg.predict([[5000]])
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# ## Considering the line: y = m * x + c, m is the coefficient and c is the intercept

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# # Visualising the data with the fitted line

# %%
# %matplotlib inline
plt.xlabel('area(sq. ft.)')
plt.ylabel('price(sq. ft.)')
plt.scatter(df.area, df.price, color = "red", marker = '+')
plt.plot(df.area, reg.predict(df[['area']]))

# %% [markdown]
# # Predicting the price for given area

# %%
d = pd.read_csv(r"C:\Users\ACER\Desktop\ML\01-Simple-Linear-Regression\areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = reg.predict(d)

# %%
d['predicted_price'] = p

# %%
d
# Out:
#     area  predicted_price
# 0   1000     3.164041e+05
# 1   1500     3.842979e+05
# 2   2300     4.929281e+05
# 3   3540     6.613048e+05
# 4   4120     7.400616e+05
# 5   4560     7.998082e+05
# 6   5490     9.260908e+05
# 7   3460     6.504418e+05
# 8   4750     8.256079e+05
# 9   2300     4.929281e+05
# 10  9000     1.402705e+06
# 11  8600     1.348390e+06
# 12  7100     1.144709e+06

# %% [markdown]
# # Adding the predicted prices to the actual data

# %%
# d.to_csv("prediction.csv", index = False)

# %% [markdown]
# # Exercise

# %%
data = pd.read_csv(r"C:\Users\ACER\Desktop\ML\01-Simple-Linear-Regression\canada_per_capita_income.csv")
data
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %% [markdown]
# # Visualising the data

# %%
plt.xlabel('year')
plt.ylabel('per capita income')
plt.scatter(data['year'], data['per capita income (US$)'], color = 'red')

# %% [markdown]
# # Fitting the line

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['year']], data['per capita income (US$)'])
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the per capita income for the year 2020

# %%
reg.predict([[2020]])
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# # Visualising the data with the fitted line

# %%
plt.xlabel('Year')
plt.ylabel('Per capita income (in US$)')
plt.scatter(data['year'], data['per capita income (US$)'], color = 'red')
plt.plot(data['year'], reg.predict(data[['year']]))
